# %%
import numpy as np
import pandas as pd
import random
import os
import logging
from typing import List, Tuple, Any
from tqdm import tqdm

import json
import pandas as pd
import numpy as np
from math import sqrt

from data import loader

# --- Constants ---
HQ_POLYGON = 18
MAX_TIME = 360  # minutes
LOADING_TIME = 30
UNLOADING_TIME = 30
TRUCK_CAPACITY = 2000

# %%
# --- Utility Functions ---
def load_polygons(filepath):
    return pd.read_csv(filepath)

def euclidean_distance(p1, p2):
    return sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def compute_time_matrix(polygon_df):
    polygons = polygon_df['Poligono'].tolist()
    coords = polygon_df.set_index('Poligono')[['X', 'Y']].to_dict('index')
    time_data = []
    for i in polygons:
        for j in polygons:
            dist = euclidean_distance(list(coords[i].values()), list(coords[j].values())) / 1000  # KM
            time_minutes = np.ceil((dist / 10) * 60)
            time_data.append({'origin': i, 'target': j, 'time': time_minutes})
    time_df = pd.DataFrame(time_data)
    return time_df.pivot(index='origin', columns='target', values='time')

# %%
# --- VRP Class ---

class VRP:
    def __init__(self, inventory_df, polygon_df):
        self.inventory_df = inventory_df.copy()
        self.polygon_df = polygon_df
        self.time_df = compute_time_matrix(polygon_df)
        self.reset()

    def reset(self):
        self.current_state = {
            'location': HQ_POLYGON,
            'time': 0,
            'load': 0,
            'inventory': [],
            'delivered': []
        }
        self.action_history = []
        self.remaining = self._get_initial_remaining()

    def _get_initial_remaining(self):
        # Aggregate demand for day 1 by polygon
        return self.inventory_df.groupby('polygon').agg({'amount': 'sum'}).reset_index()

    def get_state(self):
        return self.current_state.copy()

    def get_actions(self, state):
        actions = []
        # Load at HQ
        if state['location'] == HQ_POLYGON and state['time'] + LOADING_TIME <= MAX_TIME and not state['inventory']:
            actions.append({'type': 'load'})
        # Deliveries
        for order in state['inventory']:
            polygon = order['polygon']
            travel_time = self.time_df.at[state['location'], polygon]
            total_time = travel_time + UNLOADING_TIME + self.time_df.at[polygon, HQ_POLYGON]
            if state['location'] != polygon and state['time'] + total_time <= MAX_TIME:
                actions.append({'type': 'deliver', 'order': order})
            elif state['location'] == polygon and state['time'] + UNLOADING_TIME + self.time_df.at[polygon, HQ_POLYGON] <= MAX_TIME:
                actions.append({'type': 'deliver', 'order': order})
        # Return to HQ
        if state['location'] != HQ_POLYGON:
            travel_time = self.time_df.at[state['location'], HQ_POLYGON]
            if state['time'] + travel_time <= MAX_TIME:
                actions.append({'type': 'return'})
        return actions

    def protocol(self, actions, state):
        # Prioritize deliver > load > return
        for action in actions:
            if action['type'] == 'deliver':
                return action
        for action in actions:
            if action['type'] == 'load':
                return action
        for action in actions:
            if action['type'] == 'return':
                return action
        return None

    def apply_action(self, action):
        state = self.current_state
        if action['type'] == 'load':
            self._load_truck()
        elif action['type'] == 'deliver':
            self._deliver_order(action['order'])
        elif action['type'] == 'return':
            self._return_to_hq()

    def _load_truck(self):
        capacity = TRUCK_CAPACITY
        new_inventory = []
        new_remaining = []
        for _, row in self.remaining.iterrows():
            amount = row['amount']
            if amount <= capacity:
                new_inventory.append(row.to_dict())
                capacity -= amount
            else:
                new_remaining.append(row.to_dict())
        self.current_state['inventory'] = new_inventory
        self.remaining = pd.DataFrame(new_remaining)
        self.current_state['load'] = TRUCK_CAPACITY - capacity
        self.current_state['time'] += LOADING_TIME
        self.action_history.append(('load', len(new_inventory)))

    def _deliver_order(self, order):
        state = self.current_state
        travel_time = self.time_df.at[state['location'], order['polygon']]
        state['time'] += travel_time + UNLOADING_TIME
        state['location'] = order['polygon']
        state['inventory'].remove(order)
        state['load'] -= order['amount']
        state['delivered'].append(order)
        self.action_history.append(('deliver', order))

    def _return_to_hq(self):
        state = self.current_state
        travel_time = self.time_df.at[state['location'], HQ_POLYGON]
        state['time'] += travel_time
        state['location'] = HQ_POLYGON
        self.action_history.append(('return',))

    def run(self):
        while self.current_state['time'] < MAX_TIME:
            actions = self.get_actions(self.current_state)
            if not actions:
                break
            selected_action = self.protocol(actions, self.current_state)
            if not selected_action:
                break
            self.apply_action(selected_action)
        return self.current_state, self.action_history

# %%
# --- Warehouse Class ---

class Warehouse:
    def __init__(self):
        """
        Almacén central que guarda inventario por especie y día.
        """
        self.daily_inventory = {}  # {day: [{'polygon': x, 'specie': y, 'amount': z}]}
        self.max_capacity = TRUCK_CAPACITY * 2
        self.remaining_capacity = self.max_capacity

    def receive_deliveries(self, day: int, deliveries: List[Tuple[int, int, str, str, float]]):
        """
        Recibe entregas del proveedor (desde SASCOpt).
        """
        if day not in self.daily_inventory:
            self.daily_inventory[day] = []
        
        total_received = 0
        for _, polygon, specie, _, amount in deliveries:
            self.daily_inventory[day].append({
                'polygon': polygon,
                'specie': specie,
                'amount': amount
            })
            total_received += amount

        self.remaining_capacity -= total_received

    def get_available_orders(self, day: int) -> pd.DataFrame:
        """
        Devuelve un DataFrame con los pedidos disponibles ese día para enviar con VRP.
        Solo los pedidos que llevan al menos 3 días en el almacén están disponibles.
        """
        eligible_days = [d for d in self.daily_inventory if d <= day - 3]
        if not eligible_days:
            return pd.DataFrame(columns=['polygon', 'amount'])  # Empty

        records = []
        for d in eligible_days:
            records.extend(self.daily_inventory[d])
        if not records:
            return pd.DataFrame(columns=['polygon', 'amount'])

        df = pd.DataFrame(records)
        grouped = df.groupby('polygon').agg({'amount': 'sum'}).reset_index()
        return grouped
    
    def update_after_delivery(self, delivered_orders: List[dict], day: int):
        """
        Removes delivered orders from eligible inventory (those stored on days <= day - 3).
        Updates remaining capacity accordingly.
        """
        eligible_days = [d for d in self.daily_inventory if d <= day - 3]
        total_removed = 0

        for delivered in delivered_orders:
            found = False
            for d in eligible_days:
                current = self.daily_inventory[d]
                for i, entry in enumerate(current):
                    if entry['polygon'] == delivered['polygon']:
                        total_removed += delivered['amount']
                        current.pop(i)
                        found = True
                        break
                if found:
                    break

        self.remaining_capacity += total_removed
        print(f"[Day {day}] Freed up {total_removed} units. New capacity: {self.remaining_capacity}")

# %%
# --- SASCOpt Class ---

class SASCOpt:
    """
    Optimizes supply chain scheduling using Simulated Annealing.
    """

    def __init__(
        self,
        demand_df: pd.DataFrame,
        prices_df: pd.DataFrame,
        polygon_df: pd.DataFrame,
        max_load: int = TRUCK_CAPACITY,
        transport_cost: float = 4500,
        iterations: int = 1000,
        initial_temp: float = 10000,
        cooling_rate: float = 0.995,
        log_file: str = './output/SA_Supply_Chain.log'
    ):
        self.demand_df = demand_df.copy()
        self.prices_df = prices_df.copy()
        self.polygon_df = polygon_df.copy()
        self.max_load = max_load
        self.transport_cost = transport_cost
        self.iterations = iterations
        self.initial_temp = initial_temp
        self.cooling_rate = cooling_rate
        self.log_file = log_file

        self.demands = self._aggregate_demands()
        self.species = self.demands['specie'].unique()
        self.suppliers = self.prices_df['supplier'].unique()

        self._setup_logging()

    def _aggregate_demands(self) -> pd.DataFrame:
        """Aggregate demands by polygon and specie."""
        return self.demand_df.groupby(['polygon', 'specie'])['demand'].sum().reset_index()

    def _setup_logging(self):
        """Set up logging to file."""
        if os.path.exists(self.log_file):
            logging.shutdown()
            os.remove(self.log_file)
        logging.basicConfig(filename=self.log_file, level=logging.INFO)

    def initial_solution(self) -> List[Tuple[int, Any, Any, Any, float]]:
        """
        Generate an initial feasible solution.
        Returns:
            List of tuples: (day, polygon, specie, supplier, amount)
        """
        remaining = self.demands.copy()
        order_schedule = []
        warehouse = Warehouse()
        day = 0

        while (remaining['demand'].sum() > 0):
            print("="*50)
            print(f"\n=== Day {day + 1} ===")
            print("Initial orders to fulfill:")
            print(remaining[remaining['demand'] > 0])

            day += 1
            truck_remaining_capacity = self.max_load
            # warehouse_day_load = 0  # New!
            fulfilled_indices = []
            day_plan = []

            for idx, row in remaining[remaining['demand'] > 0].sample(frac=1).iterrows():
                polygon, specie, demand = row['polygon'], row['specie'], row['demand']

                # Check both truck capacity and warehouse cumulative capacity for today
                if (demand > truck_remaining_capacity) or (truck_remaining_capacity + demand > warehouse.remaining_capacity):
                    continue

                valid_suppliers = self.prices_df[self.prices_df['specie'] == specie]['supplier'].unique()
                if len(valid_suppliers) == 0:
                    continue

                supplier = random.choice(valid_suppliers)
                day_plan.append((day, polygon, specie, supplier, demand))
                truck_remaining_capacity -= demand
                # warehouse_day_load += demand  # Increment cumulative load
                fulfilled_indices.append(idx)

            if day_plan:
                print(f"\nRemaining truck capacity: {truck_remaining_capacity}")
                print("\nOrders scheduled for delivery to warehouse today:")
                for order in day_plan:
                    print(order)
                order_schedule.extend(day_plan)
                remaining.loc[fulfilled_indices, 'demand'] = 0

                warehouse.receive_deliveries(day, day_plan)
                print(f"\nWarehouse state after receiving deliveries: {warehouse.remaining_capacity}")
                print(warehouse.daily_inventory)
            else:
                print("No orders scheduled for delivery to warehouse today")
            
            available_inventory = warehouse.get_available_orders(day)
            print("\nAvailable inventory for VRP delivery:")
            print(available_inventory)

            vrp_optimizer = VRP(
                inventory_df=available_inventory,
                polygon_df=self.polygon_df
            )

            final_state, action_history = vrp_optimizer.run()
            print("\nOrders delivered by VRP today:")
            print(final_state['delivered'])

            warehouse.update_after_delivery(final_state['delivered'], day)
            print(f"\nWarehouse state after VRP delivery: {warehouse.remaining_capacity}")
            print(warehouse.daily_inventory)

        return order_schedule

    def fitness(self, schedule: List[Tuple[int, Any, Any, Any, float]]) -> float:
        """
        Calculate the total cost of a schedule.
        """
        cost = 0
        horizon_days = max(entry[0] for entry in schedule)
        for day in range(1, horizon_days + 1):
            day_orders = [entry for entry in schedule if entry[0] == day]
            day_suppliers = set()
            for (_, polygon, specie, supplier, amount) in day_orders:
                price_row = self.prices_df[
                    (self.prices_df['specie'] == specie) &
                    (self.prices_df['supplier'] == supplier)
                ]
                unit_price = price_row.iloc[0]['price']
                cost += unit_price * amount
                day_suppliers.add(supplier)
            cost += self.transport_cost * len(day_suppliers)
        return cost

    def neighbor(self, schedule: List[Tuple[int, Any, Any, Any, float]]) -> List[Tuple[int, Any, Any, Any, float]]:
        """
        Generate a neighbor solution by changing the supplier for a random order.
        """
        new_schedule = schedule.copy()
        if len(new_schedule) < 2:
            return new_schedule

        idx = random.randint(0, len(new_schedule) - 1)
        day, polygon, specie, _, amount = new_schedule[idx]
        valid_suppliers = self.prices_df[self.prices_df['specie'] == specie]['supplier'].unique()
        new_supplier = random.choice(valid_suppliers)
        new_schedule[idx] = (day, polygon, specie, new_supplier, amount)
        return new_schedule

    def run(self) -> Tuple[List[Tuple[int, Any, Any, Any, float]], float]:
        """
        Run the Simulated Annealing optimization.
        Returns:
            Tuple of (best_solution, best_cost)
        """
        current_solution = self.initial_solution()
        current_cost = self.fitness(current_solution)
        best_solution = current_solution
        best_cost = current_cost
        temp = self.initial_temp

        for i in tqdm(range(self.iterations)):
            new_solution = self.neighbor(current_solution)
            new_cost = self.fitness(new_solution)

            accept = new_cost < current_cost or random.random() < np.exp((current_cost - new_cost) / temp)
            if accept:
                current_solution = new_solution
                current_cost = new_cost
                if new_cost < best_cost:
                    best_solution = new_solution
                    best_cost = new_cost

            temp *= self.cooling_rate
            logging.info(f"Iteration {i+1}: Cost = {current_cost:.2f}, Temp = {temp:.2f}")

        logging.info(f"Best solution found with cost: {best_cost:.2f}")
        return best_solution, best_cost

# %%
demand_df, prices_df, polygon_df = loader.create_datasets()

sc_optimizer = SASCOpt(
    demand_df = demand_df.sample(frac=0.2),
    prices_df = prices_df,
    polygon_df = polygon_df,
)

# %%
sc_optimizer.run()
# Out:
# === Day 1 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 1         1        Opuntia engelmani     162
# 2         3        Agave lechuguilla     264
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 5         5             Agave scabra     249
# 6         5  Opuntia cantabrigiensis     294
# 7         5       Prosopis laevigata     521
# 8        16          Opuntia robusta     327
# 9        16       Prosopis laevigata     389
# 10       16           Yucca filifera     118
# 11       17        Opuntia engelmani     183
# 12       17          Opuntia robusta     354
# 13       19            Agave striata     162
# 14       19  Opuntia cantabrigiensis     192
# 15       19        Opuntia engelmani     147
# 16       20        Agave lechuguilla      45
# 17       20           Agave salmiana     216
# 18       20             Agave scabra      45
# 19       20           Yucca filifera      29
# 20       24  Opuntia cantabrigiensis     220
# 21       24          Opuntia robusta     327
# 22       25            Agave striata     166
# 23       25       Prosopis laevigata     348
# 24       26  Opuntia cantabrigiensis     185
# 25       26       Prosopis laevigata     327
#
# Remaining truck capacity: 68
#
# Orders scheduled for delivery to warehouse today:
# (1, 19, 'Agave striata', 'Moctezuma', 162)
# (1, 16, 'Yucca filifera', 'Vivero', 118)
# (1, 25, 'Prosopis laevigata', 'Vivero', 348)
# (1, 5, 'Agave scabra', 'Laguna seca', 249)
# (1, 16, 'Prosopis laevigata', 'Vivero', 389)
# (1, 24, 'Opuntia cantabrigiensis', 'Venado', 220)
# (1, 24, 'Opuntia robusta', 'Laguna seca', 327)
# (1, 20, 'Agave lechuguilla', 'Laguna seca', 45)
# (1, 20, 'Yucca filifera', 'Vivero', 29)
# (1, 20, 'Agave scabra', 'Moctezuma', 45)
#
# Warehouse state after receiving deliveries: 2068
# {1: [{'polygon': 19, 'specie': 'Agave striata', 'amount': 162}, {'polygon': 16, 'specie': 'Yucca filifera', 'amount': 118}, {'polygon': 25, 'specie': 'Prosopis laevigata', 'amount': 348}, {'polygon': 5, 'specie': 'Agave scabra', 'amount': 249}, {'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia cantabrigiensis', 'amount': 220}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Agave lechuguilla', 'amount': 45}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}]}
#
# Available inventory for VRP delivery:
# Empty DataFrame
# Columns: [polygon, amount]
# Index: []
#
# Orders delivered by VRP today:
# []
# [Day 1] Freed up 0 units. New capacity: 2068
#
# Warehouse state after VRP delivery: 2068
# {1: [{'polygon': 19, 'specie': 'Agave striata', 'amount': 162}, {'polygon': 16, 'specie': 'Yucca filifera', 'amount': 118}, {'polygon': 25, 'specie': 'Prosopis laevigata', 'amount': 348}, {'polygon': 5, 'specie': 'Agave scabra', 'amount': 249}, {'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia cantabrigiensis', 'amount': 220}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Agave lechuguilla', 'amount': 45}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}]}
#
# === Day 2 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 1         1        Opuntia engelmani     162
# 2         3        Agave lechuguilla     264
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 6         5  Opuntia cantabrigiensis     294
# 7         5       Prosopis laevigata     521
# 8        16          Opuntia robusta     327
# 11       17        Opuntia engelmani     183
# 12       17          Opuntia robusta     354
# 14       19  Opuntia cantabrigiensis     192
# 15       19        Opuntia engelmani     147
# 17       20           Agave salmiana     216
# 22       25            Agave striata     166
# 24       26  Opuntia cantabrigiensis     185
# 25       26       Prosopis laevigata     327
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
# Empty DataFrame
# Columns: [polygon, amount]
# Index: []
#
# Orders delivered by VRP today:
# []
# [Day 2] Freed up 0 units. New capacity: 2068
#
# Warehouse state after VRP delivery: 2068
# {1: [{'polygon': 19, 'specie': 'Agave striata', 'amount': 162}, {'polygon': 16, 'specie': 'Yucca filifera', 'amount': 118}, {'polygon': 25, 'specie': 'Prosopis laevigata', 'amount': 348}, {'polygon': 5, 'specie': 'Agave scabra', 'amount': 249}, {'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia cantabrigiensis', 'amount': 220}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Agave lechuguilla', 'amount': 45}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}]}
#
# === Day 3 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 1         1        Opuntia engelmani     162
# 2         3        Agave lechuguilla     264
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 6         5  Opuntia cantabrigiensis     294
# 7         5       Prosopis laevigata     521
# 8        16          Opuntia robusta     327
# 11       17        Opuntia engelmani     183
# 12       17          Opuntia robusta     354
# 14       19  Opuntia cantabrigiensis     192
# 15       19        Opuntia engelmani     147
# 17       20           Agave salmiana     216
# 22       25            Agave striata     166
# 24       26  Opuntia cantabrigiensis     185
# 25       26       Prosopis laevigata     327
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
# Empty DataFrame
# Columns: [polygon, amount]
# Index: []
#
# Orders delivered by VRP today:
# []
# [Day 3] Freed up 0 units. New capacity: 2068
#
# Warehouse state after VRP delivery: 2068
# {1: [{'polygon': 19, 'specie': 'Agave striata', 'amount': 162}, {'polygon': 16, 'specie': 'Yucca filifera', 'amount': 118}, {'polygon': 25, 'specie': 'Prosopis laevigata', 'amount': 348}, {'polygon': 5, 'specie': 'Agave scabra', 'amount': 249}, {'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia cantabrigiensis', 'amount': 220}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Agave lechuguilla', 'amount': 45}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}]}
#
# === Day 4 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 1         1        Opuntia engelmani     162
# 2         3        Agave lechuguilla     264
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 6         5  Opuntia cantabrigiensis     294
# 7         5       Prosopis laevigata     521
# 8        16          Opuntia robusta     327
# 11       17        Opuntia engelmani     183
# 12       17          Opuntia robusta     354
# 14       19  Opuntia cantabrigiensis     192
# 15       19        Opuntia engelmani     147
# 17       20           Agave salmiana     216
# 22       25            Agave striata     166
# 24       26  Opuntia cantabrigiensis     185
# 25       26       Prosopis laevigata     327
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
#    polygon  amount
# 0        5     249
# 1       16     507
# 2       19     162
# 3       20     119
# 4       24     547
# 5       25     348
#
# Orders delivered by VRP today:
# [{'polygon': 5, 'amount': 249}, {'polygon': 16, 'amount': 507}, {'polygon': 19, 'amount': 162}, {'polygon': 20, 'amount': 119}, {'polygon': 24, 'amount': 547}, {'polygon': 25, 'amount': 348}]
# [Day 4] Freed up 1932 units. New capacity: 4000
#
# Warehouse state after VRP delivery: 4000
# {1: [{'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}]}
#
# === Day 5 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 1         1        Opuntia engelmani     162
# 2         3        Agave lechuguilla     264
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 6         5  Opuntia cantabrigiensis     294
# 7         5       Prosopis laevigata     521
# 8        16          Opuntia robusta     327
# 11       17        Opuntia engelmani     183
# 12       17          Opuntia robusta     354
# 14       19  Opuntia cantabrigiensis     192
# 15       19        Opuntia engelmani     147
# 17       20           Agave salmiana     216
# 22       25            Agave striata     166
# 24       26  Opuntia cantabrigiensis     185
# 25       26       Prosopis laevigata     327
#
# Remaining truck capacity: 9
#
# Orders scheduled for delivery to warehouse today:
# (5, 3, 'Agave lechuguilla', 'Laguna seca', 264)
# (5, 5, 'Prosopis laevigata', 'Vivero', 521)
# (5, 26, 'Opuntia cantabrigiensis', 'Moctezuma', 185)
# (5, 1, 'Opuntia engelmani', 'Laguna seca', 162)
# (5, 19, 'Opuntia engelmani', 'Laguna seca', 147)
# (5, 17, 'Opuntia robusta', 'Moctezuma', 354)
# (5, 25, 'Agave striata', 'Venado', 166)
# (5, 19, 'Opuntia cantabrigiensis', 'Moctezuma', 192)
#
# Warehouse state after receiving deliveries: 2009
# {1: [{'polygon': 16, 'specie': 'Prosopis laevigata', 'amount': 389}, {'polygon': 24, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 20, 'specie': 'Yucca filifera', 'amount': 29}, {'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}], 5: [{'polygon': 3, 'specie': 'Agave lechuguilla', 'amount': 264}, {'polygon': 5, 'specie': 'Prosopis laevigata', 'amount': 521}, {'polygon': 26, 'specie': 'Opuntia cantabrigiensis', 'amount': 185}, {'polygon': 1, 'specie': 'Opuntia engelmani', 'amount': 162}, {'polygon': 19, 'specie': 'Opuntia engelmani', 'amount': 147}, {'polygon': 17, 'specie': 'Opuntia robusta', 'amount': 354}, {'polygon': 25, 'specie': 'Agave striata', 'amount': 166}, {'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}]}
#
# Available inventory for VRP delivery:
#    polygon  amount
# 0       16     389
# 1       20      74
# 2       24     327
#
# Orders delivered by VRP today:
# [{'polygon': 16, 'amount': 389}, {'polygon': 20, 'amount': 74}, {'polygon': 24, 'amount': 327}]
# [Day 5] Freed up 790 units. New capacity: 2799
#
# Warehouse state after VRP delivery: 2799
# {1: [{'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}], 5: [{'polygon': 3, 'specie': 'Agave lechuguilla', 'amount': 264}, {'polygon': 5, 'specie': 'Prosopis laevigata', 'amount': 521}, {'polygon': 26, 'specie': 'Opuntia cantabrigiensis', 'amount': 185}, {'polygon': 1, 'specie': 'Opuntia engelmani', 'amount': 162}, {'polygon': 19, 'specie': 'Opuntia engelmani', 'amount': 147}, {'polygon': 17, 'specie': 'Opuntia robusta', 'amount': 354}, {'polygon': 25, 'specie': 'Agave striata', 'amount': 166}, {'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}]}
#
# === Day 6 ===
# Initial orders to fulfill:
#     polygon                   specie  demand
# 0         1  Opuntia cantabrigiensis     210
# 3         3           Agave salmiana    1254
# 4         4        Opuntia engelmani     240
# 6         5  Opuntia cantabrigiensis     294
# 8        16          Opuntia robusta     327
# 11       17        Opuntia engelmani     183
# 17       20           Agave salmiana     216
# 25       26       Prosopis laevigata     327
#
# Remaining truck capacity: 203
#
# Orders scheduled for delivery to warehouse today:
# (6, 26, 'Prosopis laevigata', 'Vivero', 327)
# (6, 16, 'Opuntia robusta', 'Laguna seca', 327)
# (6, 5, 'Opuntia cantabrigiensis', 'Venado', 294)
# (6, 17, 'Opuntia engelmani', 'Laguna seca', 183)
# (6, 4, 'Opuntia engelmani', 'Venado', 240)
# (6, 20, 'Agave salmiana', 'Laguna seca', 216)
# (6, 1, 'Opuntia cantabrigiensis', 'Moctezuma', 210)
#
# Warehouse state after receiving deliveries: 1002
# {1: [{'polygon': 20, 'specie': 'Agave scabra', 'amount': 45}], 5: [{'polygon': 3, 'specie': 'Agave lechuguilla', 'amount': 264}, {'polygon': 5, 'specie': 'Prosopis laevigata', 'amount': 521}, {'polygon': 26, 'specie': 'Opuntia cantabrigiensis', 'amount': 185}, {'polygon': 1, 'specie': 'Opuntia engelmani', 'amount': 162}, {'polygon': 19, 'specie': 'Opuntia engelmani', 'amount': 147}, {'polygon': 17, 'specie': 'Opuntia robusta', 'amount': 354}, {'polygon': 25, 'specie': 'Agave striata', 'amount': 166}, {'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}], 6: [{'polygon': 26, 'specie': 'Prosopis laevigata', 'amount': 327}, {'polygon': 16, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 5, 'specie': 'Opuntia cantabrigiensis', 'amount': 294}, {'polygon': 17, 'specie': 'Opuntia engelmani', 'amount': 183}, {'polygon': 4, 'specie': 'Opuntia engelmani', 'amount': 240}, {'polygon': 20, 'specie': 'Agave salmiana', 'amount': 216}, {'polygon': 1, 'specie': 'Opuntia cantabrigiensis', 'amount': 210}]}
#
# Available inventory for VRP delivery:
#    polygon  amount
# 0       20      45
#
# Orders delivered by VRP today:
# [{'polygon': 20, 'amount': 45}]
# [Day 6] Freed up 45 units. New capacity: 1047
#
# Warehouse state after VRP delivery: 1047
# {1: [], 5: [{'polygon': 3, 'specie': 'Agave lechuguilla', 'amount': 264}, {'polygon': 5, 'specie': 'Prosopis laevigata', 'amount': 521}, {'polygon': 26, 'specie': 'Opuntia cantabrigiensis', 'amount': 185}, {'polygon': 1, 'specie': 'Opuntia engelmani', 'amount': 162}, {'polygon': 19, 'specie': 'Opuntia engelmani', 'amount': 147}, {'polygon': 17, 'specie': 'Opuntia robusta', 'amount': 354}, {'polygon': 25, 'specie': 'Agave striata', 'amount': 166}, {'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}], 6: [{'polygon': 26, 'specie': 'Prosopis laevigata', 'amount': 327}, {'polygon': 16, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 5, 'specie': 'Opuntia cantabrigiensis', 'amount': 294}, {'polygon': 17, 'specie': 'Opuntia engelmani', 'amount': 183}, {'polygon': 4, 'specie': 'Opuntia engelmani', 'amount': 240}, {'polygon': 20, 'specie': 'Agave salmiana', 'amount': 216}, {'polygon': 1, 'specie': 'Opuntia cantabrigiensis', 'amount': 210}]}
#
# === Day 7 ===
# Initial orders to fulfill:
#    polygon          specie  demand
# 3        3  Agave salmiana    1254
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
# Empty DataFrame
# Columns: [polygon, amount]
# Index: []
#
# Orders delivered by VRP today:
# []
# [Day 7] Freed up 0 units. New capacity: 1047
#
# Warehouse state after VRP delivery: 1047
# {1: [], 5: [{'polygon': 3, 'specie': 'Agave lechuguilla', 'amount': 264}, {'polygon': 5, 'specie': 'Prosopis laevigata', 'amount': 521}, {'polygon': 26, 'specie': 'Opuntia cantabrigiensis', 'amount': 185}, {'polygon': 1, 'specie': 'Opuntia engelmani', 'amount': 162}, {'polygon': 19, 'specie': 'Opuntia engelmani', 'amount': 147}, {'polygon': 17, 'specie': 'Opuntia robusta', 'amount': 354}, {'polygon': 25, 'specie': 'Agave striata', 'amount': 166}, {'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}], 6: [{'polygon': 26, 'specie': 'Prosopis laevigata', 'amount': 327}, {'polygon': 16, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 5, 'specie': 'Opuntia cantabrigiensis', 'amount': 294}, {'polygon': 17, 'specie': 'Opuntia engelmani', 'amount': 183}, {'polygon': 4, 'specie': 'Opuntia engelmani', 'amount': 240}, {'polygon': 20, 'specie': 'Agave salmiana', 'amount': 216}, {'polygon': 1, 'specie': 'Opuntia cantabrigiensis', 'amount': 210}]}
#
# === Day 8 ===
# Initial orders to fulfill:
#    polygon          specie  demand
# 3        3  Agave salmiana    1254
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
#    polygon  amount
# 0        1     162
# 1        3     264
# 2        5     521
# 3       17     354
# 4       19     339
# 5       25     166
# 6       26     185
#
# Orders delivered by VRP today:
# [{'polygon': 1, 'amount': 162}, {'polygon': 3, 'amount': 264}, {'polygon': 5, 'amount': 521}, {'polygon': 17, 'amount': 354}, {'polygon': 19, 'amount': 339}, {'polygon': 25, 'amount': 166}, {'polygon': 26, 'amount': 185}]
# [Day 8] Freed up 1991 units. New capacity: 3038
#
# Warehouse state after VRP delivery: 3038
# {1: [], 5: [{'polygon': 19, 'specie': 'Opuntia cantabrigiensis', 'amount': 192}], 6: [{'polygon': 26, 'specie': 'Prosopis laevigata', 'amount': 327}, {'polygon': 16, 'specie': 'Opuntia robusta', 'amount': 327}, {'polygon': 5, 'specie': 'Opuntia cantabrigiensis', 'amount': 294}, {'polygon': 17, 'specie': 'Opuntia engelmani', 'amount': 183}, {'polygon': 4, 'specie': 'Opuntia engelmani', 'amount': 240}, {'polygon': 20, 'specie': 'Agave salmiana', 'amount': 216}, {'polygon': 1, 'specie': 'Opuntia cantabrigiensis', 'amount': 210}]}
#
# === Day 9 ===
# Initial orders to fulfill:
#    polygon          specie  demand
# 3        3  Agave salmiana    1254
# No orders scheduled for delivery to warehouse today
#
# Available inventory for VRP delivery:
#    polygon  amount
# 0        1     210
# 1        4     240
# 2        5     294
# 3       16     327
# 4       17     183
# 5       19     192
# 6       20     216
# 7       26     327
#
# Orders delivered by VRP today:
# [{'polygon': 1, 'amount': 210}, {'polygon': 4, 'amount': 240}, {'polygon': 5, 'amount': 294}, {'polygon': 16, 'amount': 327}, {'polygon': 17, 'amount': 183}, {'polygon': 19, 'amount': 192}, {'polygon': 20, 'amount': 216}, {'polygon': 26, 'amount': 327}]
# [Day 9] Freed up 1989 units. New capacity: 5027
#
# Warehouse state after VRP delivery: 5027
# {1: [], 5: [], 6: []}
#
# === Day 10 ===
# Initial orders to fulfill:
#    polygon          specie  demand
# 3        3  Agave salmiana    1254
#
# Remaining truck capacity: 746
#
# Orders scheduled for delivery to warehouse today:
# (10, 3, 'Agave salmiana', 'Laguna seca', 1254)
#
# Warehouse state after receiving deliveries: 3773
# {1: [], 5: [], 6: [], 10: [{'polygon': 3, 'specie': 'Agave salmiana', 'amount': 1254}]}
#
# Available inventory for VRP delivery:
# Empty DataFrame
# Columns: [polygon, amount]
# Index: []
#
# Orders delivered by VRP today:
# []
# [Day 10] Freed up 0 units. New capacity: 3773
#
# Warehouse state after VRP delivery: 3773
# {1: [], 5: [], 6: [], 10: [{'polygon': 3, 'specie': 'Agave salmiana', 'amount': 1254}]}
#  16%|█▌        | 157/1000 [00:02<00:11, 71.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sc_optimizer.run()
#
# Cell In[54], line 166, in SASCOpt.run(self)
#     163 best_cost = current_cost
#     164 temp = self.initial_temp
# --> 166 for i in tqdm(range(self.iterations)):
#     167     new_solution = self.neighbor(current_solution)
#     168     new_cost = self.fitness(new_solution)
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:1191, in tqdm.__iter__(self)
#    1189 dt = cur_t - last_print_t
#    1190 if dt >= mininterval and cur_t >= min_start_t:
# -> 1191     self.update(n - last_print_n)
#    1192     last_print_n = self.last_print_n
#    1193     last_print_t = self.last_print_t
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\std.py:453, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
#     452     fp.write(str(s))
# --> 453     fp_flush()
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\tqdm\utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File c:\Users\rcorr\anaconda3\envs\DS\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
