# %%
import numpy as np
import sympy as sp

# %%
# Define a symbolic function
x, y = sp.symbols('x y')
f = 5*x**2 + 2*y**2

# Compute symbolic gradients
grad_f = [sp.diff(f, var) for var in (x, y)]

# Convert symbolic gradients to numerical functions
grad_f_num = [sp.lambdify((x, y), g, 'numpy') for g in grad_f]

# Nesterov momentum parameters
learning_rate = 0.1
momentum = 0.9
point = np.array([1.5, 2.0])
velocity = np.zeros_like(point)

epsilon = np.inf
iteration = 0

while epsilon > 0.1:
    iteration += 1
    # Lookahead point
    lookahead = (point + momentum * velocity).round(3)
    grad = np.array([g(lookahead[0], lookahead[1]) for g in grad_f_num]).round(3)
    epsilon = np.linalg.norm(grad).round(3)
    velocity = (momentum * velocity - learning_rate * (1 - momentum) * grad).round(3)
    point += np.round(velocity, 3)

    print(f"Iteration {iteration}")
    print(f"Lookahead: {lookahead}")
    print(f"Grad at lookahead: {grad}")
    print(f"Velocity: {velocity}")
    print(f"Minimum at: {point}")
    print(f"Grad norm: {epsilon}")
    print("="*40)
# Out:
# Iteration 1
# Lookahead: [1.5 2. ]
# Grad at lookahead: [15.  8.]
# Velocity: [-0.15 -0.08]
# Minimum at: [1.35 1.92]
# Grad norm: 17.0
# ========================================
# Iteration 2
# Lookahead: [1.215 1.848]
# Grad at lookahead: [12.15   7.392]
# Velocity: [-0.256 -0.146]
# Minimum at: [1.094 1.774]
# Grad norm: 14.222
# ========================================
# Iteration 3
# Lookahead: [0.864 1.643]
# Grad at lookahead: [8.64  6.572]
# Velocity: [-0.317 -0.197]
# Minimum at: [0.777 1.577]
# Grad norm: 10.855
# ========================================
# Iteration 4
# Lookahead: [0.492 1.4  ]
# Grad at lookahead: [4.92 5.6 ]
# Velocity: [-0.334 -0.233]
# Minimum at: [0.443 1.344]
# Grad norm: 7.454
# ========================================
# Iteration 5
# Lookahead: [0.142 1.134]
# Grad at lookahead: [1.42  4.536]
# Velocity: [-0.315 -0.255]
# Minimum at: [0.128 1.089]
# Grad norm: 4.753
# ========================================
# Iteration 6
# Lookahead: [-0.155  0.859]
# Grad at lookahead: [-1.55   3.436]
# Velocity: [-0.268 -0.264]
# Minimum at: [-0.14   0.825]
# Grad norm: 3.769
# ========================================
# Iteration 7
# Lookahead: [-0.381  0.587]
# Grad at lookahead: [-3.81   2.348]
# Velocity: [-0.203 -0.261]
# Minimum at: [-0.343  0.564]
# Grad norm: 4.475
# ========================================
# Iteration 8
# Lookahead: [-0.526  0.329]
# Grad at lookahead: [-5.26   1.316]
# Velocity: [-0.13  -0.248]
# Minimum at: [-0.473  0.316]
# Grad norm: 5.422
# ========================================
# Iteration 9
# Lookahead: [-0.59   0.093]
# Grad at lookahead: [-5.9    0.372]
# Velocity: [-0.058 -0.227]
# Minimum at: [-0.531  0.089]
# Grad norm: 5.912
# ========================================
# Iteration 10
# Lookahead: [-0.583 -0.115]
# Grad at lookahead: [-5.83 -0.46]
# Velocity: [ 0.006 -0.2  ]
# Minimum at: [-0.525 -0.111]
# Grad norm: 5.848
# ========================================
# Iteration 11
# Lookahead: [-0.52  -0.291]
# Grad at lookahead: [-5.2   -1.164]
# Velocity: [ 0.057 -0.168]
# Minimum at: [-0.468 -0.279]
# Grad norm: 5.329
# ========================================
# Iteration 12
# Lookahead: [-0.417 -0.43 ]
# Grad at lookahead: [-4.17 -1.72]
# Velocity: [ 0.093 -0.134]
# Minimum at: [-0.375 -0.413]
# Grad norm: 4.511
# ========================================
# Iteration 13
# Lookahead: [-0.291 -0.534]
# Grad at lookahead: [-2.91  -2.136]
# Velocity: [ 0.113 -0.099]
# Minimum at: [-0.262 -0.512]
# Grad norm: 3.61
# ========================================
# Iteration 14
# Lookahead: [-0.16  -0.601]
# Grad at lookahead: [-1.6   -2.404]
# Velocity: [ 0.118 -0.065]
# Minimum at: [-0.144 -0.577]
# Grad norm: 2.888
# ========================================
# Iteration 15
# Lookahead: [-0.038 -0.636]
# Grad at lookahead: [-0.38  -2.544]
# Velocity: [ 0.11  -0.033]
# Minimum at: [-0.034 -0.61 ]
# Grad norm: 2.572
# ========================================
# Iteration 16
# Lookahead: [ 0.065 -0.64 ]
# Grad at lookahead: [ 0.65 -2.56]
# Velocity: [ 0.092 -0.004]
# Minimum at: [ 0.058 -0.614]
# Grad norm: 2.641
# ========================================
# Iteration 17
# Lookahead: [ 0.141 -0.618]
# Grad at lookahead: [ 1.41  -2.472]
# Velocity: [0.069 0.021]
# Minimum at: [ 0.127 -0.593]
# Grad norm: 2.846
# ========================================
# Iteration 18
# Lookahead: [ 0.189 -0.574]
# Grad at lookahead: [ 1.89  -2.296]
# Velocity: [0.043 0.042]
# Minimum at: [ 0.17  -0.551]
# Grad norm: 2.974
# ========================================
# Iteration 19
# Lookahead: [ 0.209 -0.513]
# Grad at lookahead: [ 2.09  -2.052]
# Velocity: [0.018 0.058]
# Minimum at: [ 0.188 -0.493]
# Grad norm: 2.929
# ========================================
# Iteration 20
# Lookahead: [ 0.204 -0.441]
# Grad at lookahead: [ 2.04  -1.764]
# Velocity: [-0.004  0.07 ]
# Minimum at: [ 0.184 -0.423]
# Grad norm: 2.697
# ========================================
# Iteration 21
# Lookahead: [ 0.18 -0.36]
# Grad at lookahead: [ 1.8  -1.44]
# Velocity: [-0.022  0.077]
# Minimum at: [ 0.162 -0.346]
# Grad norm: 2.305
# ========================================
# Iteration 22
# Lookahead: [ 0.142 -0.277]
# Grad at lookahead: [ 1.42  -1.108]
# Velocity: [-0.034  0.08 ]
# Minimum at: [ 0.128 -0.266]
# Grad norm: 1.801
# ========================================
# Iteration 23
# Lookahead: [ 0.097 -0.194]
# Grad at lookahead: [ 0.97  -0.776]
# Velocity: [-0.04  0.08]
# Minimum at: [ 0.088 -0.186]
# Grad norm: 1.242
# ========================================
# Iteration 24
# Lookahead: [ 0.052 -0.114]
# Grad at lookahead: [ 0.52  -0.456]
# Velocity: [-0.041  0.077]
# Minimum at: [ 0.047 -0.109]
# Grad norm: 0.692
# ========================================
# Iteration 25
# Lookahead: [ 0.01 -0.04]
# Grad at lookahead: [ 0.1  -0.16]
# Velocity: [-0.038  0.071]
# Minimum at: [ 0.009 -0.038]
# Grad norm: 0.189
# ========================================
# Iteration 26
# Lookahead: [-0.025  0.026]
# Grad at lookahead: [-0.25   0.104]
# Velocity: [-0.032  0.063]
# Minimum at: [-0.023  0.025]
# Grad norm: 0.271
# ========================================
# Iteration 27
# Lookahead: [-0.052  0.082]
# Grad at lookahead: [-0.52   0.328]
# Velocity: [-0.024  0.053]
# Minimum at: [-0.047  0.078]
# Grad norm: 0.615
# ========================================
# Iteration 28
# Lookahead: [-0.069  0.126]
# Grad at lookahead: [-0.69   0.504]
# Velocity: [-0.015  0.043]
# Minimum at: [-0.062  0.121]
# Grad norm: 0.854
# ========================================
# Iteration 29
# Lookahead: [-0.075  0.16 ]
# Grad at lookahead: [-0.75  0.64]
# Velocity: [-0.006  0.032]
# Minimum at: [-0.068  0.153]
# Grad norm: 0.986
# ========================================
# Iteration 30
# Lookahead: [-0.073  0.182]
# Grad at lookahead: [-0.73   0.728]
# Velocity: [0.002 0.022]
# Minimum at: [-0.066  0.175]
# Grad norm: 1.031
# ========================================
# Iteration 31
# Lookahead: [-0.064  0.195]
# Grad at lookahead: [-0.64  0.78]
# Velocity: [0.008 0.012]
# Minimum at: [-0.058  0.187]
# Grad norm: 1.009
# ========================================
# Iteration 32
# Lookahead: [-0.051  0.198]
# Grad at lookahead: [-0.51   0.792]
# Velocity: [0.012 0.003]
# Minimum at: [-0.046  0.19 ]
# Grad norm: 0.942
# ========================================
# Iteration 33
# Lookahead: [-0.035  0.193]
# Grad at lookahead: [-0.35   0.772]
# Velocity: [ 0.014 -0.005]
# Minimum at: [-0.032  0.185]
# Grad norm: 0.848
# ========================================
# Iteration 34
# Lookahead: [-0.019  0.18 ]
# Grad at lookahead: [-0.19  0.72]
# Velocity: [ 0.014 -0.012]
# Minimum at: [-0.018  0.173]
# Grad norm: 0.745
# ========================================
# Iteration 35
# Lookahead: [-0.005  0.162]
# Grad at lookahead: [-0.05   0.648]
# Velocity: [ 0.013 -0.017]
# Minimum at: [-0.005  0.156]
# Grad norm: 0.65
# ========================================
# Iteration 36
# Lookahead: [0.007 0.141]
# Grad at lookahead: [0.07  0.564]
# Velocity: [ 0.011 -0.021]
# Minimum at: [0.006 0.135]
# Grad norm: 0.568
# ========================================
# Iteration 37
# Lookahead: [0.016 0.116]
# Grad at lookahead: [0.16  0.464]
# Velocity: [ 0.008 -0.024]
# Minimum at: [0.014 0.111]
# Grad norm: 0.491
# ========================================
# Iteration 38
# Lookahead: [0.021 0.089]
# Grad at lookahead: [0.21  0.356]
# Velocity: [ 0.005 -0.025]
# Minimum at: [0.019 0.086]
# Grad norm: 0.413
# ========================================
# Iteration 39
# Lookahead: [0.024 0.063]
# Grad at lookahead: [0.24  0.252]
# Velocity: [ 0.002 -0.025]
# Minimum at: [0.021 0.061]
# Grad norm: 0.348
# ========================================
# Iteration 40
# Lookahead: [0.023 0.038]
# Grad at lookahead: [0.23  0.152]
# Velocity: [-0.    -0.024]
# Minimum at: [0.021 0.037]
# Grad norm: 0.276
# ========================================
# Iteration 41
# Lookahead: [0.021 0.015]
# Grad at lookahead: [0.21 0.06]
# Velocity: [-0.002 -0.022]
# Minimum at: [0.019 0.015]
# Grad norm: 0.218
# ========================================
# Iteration 42
# Lookahead: [ 0.017 -0.005]
# Grad at lookahead: [ 0.17 -0.02]
# Velocity: [-0.004 -0.02 ]
# Minimum at: [ 0.015 -0.005]
# Grad norm: 0.171
# ========================================
# Iteration 43
# Lookahead: [ 0.011 -0.023]
# Grad at lookahead: [ 0.11  -0.092]
# Velocity: [-0.005 -0.017]
# Minimum at: [ 0.01  -0.022]
# Grad norm: 0.143
# ========================================
# Iteration 44
# Lookahead: [ 0.006 -0.037]
# Grad at lookahead: [ 0.06  -0.148]
# Velocity: [-0.005 -0.014]
# Minimum at: [ 0.005 -0.036]
# Grad norm: 0.16
# ========================================
# Iteration 45
# Lookahead: [ 0.001 -0.049]
# Grad at lookahead: [ 0.01  -0.196]
# Velocity: [-0.005 -0.011]
# Minimum at: [ 7.80625564e-17 -4.70000000e-02]
# Grad norm: 0.196
# ========================================
# Iteration 46
# Lookahead: [-0.004 -0.057]
# Grad at lookahead: [-0.04  -0.228]
# Velocity: [-0.004 -0.008]
# Minimum at: [-0.004 -0.055]
# Grad norm: 0.231
# ========================================
# Iteration 47
# Lookahead: [-0.008 -0.062]
# Grad at lookahead: [-0.08  -0.248]
# Velocity: [-0.003 -0.005]
# Minimum at: [-0.007 -0.06 ]
# Grad norm: 0.261
# ========================================
# Iteration 48
# Lookahead: [-0.01  -0.065]
# Grad at lookahead: [-0.1  -0.26]
# Velocity: [-0.002 -0.002]
# Minimum at: [-0.009 -0.062]
# Grad norm: 0.279
# ========================================
# Iteration 49
# Lookahead: [-0.011 -0.064]
# Grad at lookahead: [-0.11  -0.256]
# Velocity: [-0.001  0.001]
# Minimum at: [-0.01  -0.061]
# Grad norm: 0.279
# ========================================
# Iteration 50
# Lookahead: [-0.011 -0.06 ]
# Grad at lookahead: [-0.11 -0.24]
# Velocity: [0.    0.003]
# Minimum at: [-0.01  -0.058]
# Grad norm: 0.264
# ========================================
# Iteration 51
# Lookahead: [-0.01  -0.055]
# Grad at lookahead: [-0.1  -0.22]
# Velocity: [0.001 0.005]
# Minimum at: [-0.009 -0.053]
# Grad norm: 0.242
# ========================================
# Iteration 52
# Lookahead: [-0.008 -0.049]
# Grad at lookahead: [-0.08  -0.196]
# Velocity: [0.002 0.006]
# Minimum at: [-0.007 -0.047]
# Grad norm: 0.212
# ========================================
# Iteration 53
# Lookahead: [-0.005 -0.042]
# Grad at lookahead: [-0.05  -0.168]
# Velocity: [0.002 0.007]
# Minimum at: [-0.005 -0.04 ]
# Grad norm: 0.175
# ========================================
# Iteration 54
# Lookahead: [-0.003 -0.034]
# Grad at lookahead: [-0.03  -0.136]
# Velocity: [0.002 0.008]
# Minimum at: [-0.003 -0.032]
# Grad norm: 0.139
# ========================================
# Iteration 55
# Lookahead: [-0.001 -0.025]
# Grad at lookahead: [-0.01 -0.1 ]
# Velocity: [0.002 0.008]
# Minimum at: [-0.001 -0.024]
# Grad norm: 0.1
# ========================================

# %%
f.subs({x: -0.343, y: 0.564})
# Out:
# 1.22443700000000
